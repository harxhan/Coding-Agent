# %%
import sys

print("---- sys.path ----")
for p in sys.path:
    print(p)
print("------------------")
# Out:
# ---- sys.path ----
# C:\Users\Harshan\AppData\Local\Programs\Python\Python313\python313.zip
# C:\Users\Harshan\AppData\Local\Programs\Python\Python313\DLLs
# C:\Users\Harshan\AppData\Local\Programs\Python\Python313\Lib
# C:\Users\Harshan\AppData\Local\Programs\Python\Python313
# c:\Harshan's Data\Projects\Dev\Development\App-Backend\.venv
#
# c:\Harshan's Data\Projects\Dev\Development\App-Backend\.venv\Lib\site-packages
# ------------------
